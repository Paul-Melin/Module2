# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
temp=pd.read_csv(r'C:\Users\paul\Documents\Formation Data Analyst\Bootcamp\Module 2\Lab_10_Subsetting_and_Descriptive_Statistics\Temp_States.csv')
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Print `temp`.

# %%
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York.

# %%
nyc=temp[temp['State']=='New York']
nyc
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
nyc['Temperature'].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
hot_city=temp[temp['Temperature'] > 15]
hot_city
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
cold_city=temp[temp['Temperature'] < 15]
cold_city
# Out:
#          City        State  Temperature
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 4  Bridgeport  Connecticut    14.444444

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
temperate_city=temp[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)]
temperate_city
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
mean_state=temp.groupby('State')['Temperature'].mean()
mean_state
# Out:
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
# Name: Temperature, dtype: float64

# %%
std_state=temp.groupby('State')['Temperature'].std()
std_state
# Out:
# State
# Connecticut    1.964186
# New Jersey     1.571348
# New York       8.133404
# Name: Temperature, dtype: float64

# %% [markdown]
# #  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
employees=pd.read_csv(r'C:\Users\paul\Documents\Formation Data Analyst\Bootcamp\Module 2\Lab_10_Subsetting_and_Descriptive_Statistics\Employees.csv')
employees
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
print(employees)
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %%
employees.dtypes
# Out:
# Department    object
# Education     object
# Title         object
# Name          object
# Years          int64
# Salary         int64
# dtype: object

# %%
employees.describe()
# Out:
#             Years      Salary
# count  500.000000  500.000000
# mean     7.556000   73.528000
# std      4.465731   26.890061
# min      1.000000   30.000000
# 25%      3.000000   50.000000
# 50%      7.000000   72.000000
# 75%     11.250000   97.000000
# max     15.000000  120.000000

# %% [markdown]
# #### What's the average salary in this company?

# %%
employees['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# #### What's the highest salary?

# %%
employees['Salary'].max()
# Out:
# 120

# %% [markdown]
# #### What's the lowest salary?

# %%
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
low_salary=employees.groupby('Department')['Salary'].mean()
low_salary
# Out:
# Department
# Admin    76.325203
# HR       74.237705
# IT       70.671642
# Sales    73.132231
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
employees[employees['Name'] =='David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
employees['Salary'][employees['Name'] =='David']
# Out:
# 0      58
# 124    31
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
employees[employees['Title'] =='associate']
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
employees.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
employees[0:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
employees[(employees['Title'] =='associate') & (employees['Salary'] > 55)]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
employees.groupby('Years')['Salary'].agg(['mean'])
# Out:
#             mean
# Years
# 1      75.863636
# 2      75.857143
# 3      74.571429
# 4      77.129032
# 5      73.857143
# 6      72.382353
# 7      73.840000
# 8      64.250000
# 9      76.741935
# 10     73.351351
# 11     74.866667
# 12     73.454545
# 13     71.935484
# 14     70.968750
# 15     69.758621

# %% [markdown]
# ####  What is the average salary per title?

# %%
employees.groupby('Title')['Salary'].agg(['mean'])
# Out:
#                 mean
# Title
# Analyst    73.703911
# VP         72.907975
# associate  73.968354

# %% [markdown]
# ####  Find the salary quartiles.

# %%
employees['Salary'].quantile([0,0.25,0.5,0.75,1])
# Out:
# 0.00     30.0
# 0.25     50.0
# 0.50     72.0
# 0.75     97.0
# 1.00    120.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
## No information about gender in the df.

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
employees.groupby('Department')['Salary','Years'].agg(['mean', 'max', 'min'])
# Out:
# <ipython-input-30-ea58fe35f64f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   employees.groupby('Department')['Salary','Years'].agg(['mean', 'max', 'min'])
#                Salary              Years
#                  mean  max min      mean max min
# Department
# Admin       76.325203  120  30  7.642276  15   1
# HR          74.237705  119  30  7.172131  15   1
# IT          70.671642  120  30  8.141791  15   1
# Sales       73.132231  120  30  7.206612  15   1

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

# %% [markdown]
# # Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
orders=pd.read_excel(r'C:\Users\paul\Documents\Formation Data Analyst\Bootcamp\Module 2\Lab_10_Subsetting_and_Descriptive_Statistics\Orders.xlsx')

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   white hanging heart t-light holder         6 2010-12-01 08:26:00
# 1                  white metal lantern         6 2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8 2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6 2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %%
orders.dtypes
# Out:
# Unnamed: 0               int64
# InvoiceNo                int64
# StockCode               object
# year                     int64
# month                    int64
# day                      int64
# hour                     int64
# Description             object
# Quantity                 int64
# InvoiceDate     datetime64[ns]
# UnitPrice              float64
# CustomerID               int64
# Country                 object
# amount_spent           float64
# dtype: object

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average purchase price?

# %%
orders['UnitPrice'].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
orders['UnitPrice'].min()
# Out:
# 0.0

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
spain_cust=orders[orders['Country']=='Spain'].groupby('CustomerID').agg('mean')
spain_cust
# Out:
#                Unnamed: 0      InvoiceNo         year      month       day  \
# CustomerID
# 12354       166295.500000  550911.000000  2011.000000   4.000000  4.000000
# 12417       171232.000000  551398.000000  2011.000000   4.000000  4.000000
# 12421       262510.622222  559281.933333  2011.000000   6.266667  3.955556
# 12442       531425.500000  580955.000000  2011.000000  12.000000  2.000000
# 12445       478970.500000  577125.000000  2011.000000  11.000000  4.000000
# 12448       420313.500000  572886.000000  2011.000000  10.000000  3.000000
# 12450       237307.750000  557764.250000  2011.000000   6.250000  6.000000
# 12454       398633.000000  571255.000000  2011.000000  10.000000  5.000000
# 12455       289392.520833  562199.083333  2011.000000   7.625000  3.250000
# 12462       227907.209677  555628.580645  2011.000000   5.193548  2.290323
# 12484       247955.401734  558315.846821  2011.000000   6.219653  5.511561
# ...

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
len(spain_cust)
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
good_client = orders.groupby('CustomerID')['Quantity'].agg(['sum'])
good_client[good_client['sum']>50]
# Out:
#               sum
# CustomerID
# 12346       74215
# 12347        2458
# 12348        2341
# 12349         631
# 12350         197
# ...           ...
# 18278          66
# 18281          54
# 18282         103
# 18283        1397
# 18287        1586
#
# [4091 rows x 1 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
orders[orders.Country=='Spain'][orders.Quantity > 50]
# Out:
# <ipython-input-42-783beec3c008>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   orders[orders.Country=='Spain'][orders.Quantity > 50]
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# ...

# %% [markdown]
# #### Select all free orders.

# %%
free_orders=orders[orders['amount_spent']==0]
free_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
lunch_bag=orders[orders['Description'].str.startswith('lunch bag')]
lunch_bag
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10 2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
lunch_bag[lunch_bag['year']==2011]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10 2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
import matplotlib.pyplot as plt
spain_order=orders[orders.Country=='Spain']
spain_order.hist(column='amount_spent', bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'amount_spent'}>]], dtype=object)

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
august_order=orders[orders['month']=='8']
august_order
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, InvoiceNo, StockCode, year, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, amount_spent]
# Index: []

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
august_order['Country'].value_counts()
# Out:
# Series([], Name: Country, dtype: int64)

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
orders.groupby('Country')['amount_spent'].agg(['mean'])
# Out:
#                             mean
# Country
# Australia             116.895620
# Austria                25.624824
# Bahrain                32.258824
# Belgium                20.283772
# Brazil                 35.737500
# Canada                 24.280662
# Channel Islands        27.340160
# Cyprus                 22.134169
# Czech Republic         33.069600
# Denmark                49.882474
# EIRE                   36.687745
# European Community     21.670833
# Finland                32.913985
# France                 25.056827
# Germany                25.311562
# Greece                 32.831172
# Iceland                23.681319
# Israel                 29.119718
# Italy                  23.064960
# Japan                 116.561900
# Lebanon                37.641778
# Lithuania              47.458857
# Malta                  24.335625
# Netherlands           120.798282
# Norway                 33.736418
# Poland                 22.226212
# Portugal               22.872702
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
exp_item=orders['UnitPrice'].max()
exp_item
# Out:
# 8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
orders.groupby('year')['amount_spent'].agg(['mean'])
# Out:
#            mean
# year
# 2010  21.892733
# 2011  22.430074
